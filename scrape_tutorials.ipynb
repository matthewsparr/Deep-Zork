# %%
import urllib
import requests
from bs4 import BeautifulSoup
import re
import ast
import nltk
from nltk import sent_tokenize
import string
import pickle
from spacy.matcher import Matcher
from spacy.attrs import POS
import spacy
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nlp = spacy.load('en_core_web_sm')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\sparr\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sparr\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def open_tutorial_text():
    tutorials = open('tutorials.txt', 'w')
    return tutorials

# %%
def download_tutorial(url):
    #text = urllib.request.urlopen(url).read()
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.content, "lxml")
    texts = soup.findAll(text=True, strip=True)
    x = ""
    for i in texts:
        x = x + i
    req = urllib.request.Request(url,headers={'User-Agent': 'Mozilla/5.0'}) 
    text = urllib.request.urlopen(req).read().decode('utf-8')
    text = re.sub(r'([^\s\w]|_)+', '', text)
    return text

# %%
def add_tutorial_to_file(tutorials, text):
    tutorials.write(text)

# %%
def get_links(link, site):

    return_links = []

    r = requests.get(link)

    soup = BeautifulSoup(r.content, "lxml")

    if r.status_code != 200:
        print("Error. Something is wrong here")
    else:
        for link in soup.findAll('a', attrs={'href': re.compile("^")}):
            address = link.get('href')
            if ('.txt' in address):
                if (site == 1):
                    return_links.append('https://www.ifarchive.org/' + address.replace('../../../', ''))
                else:
                    return_links.append('http://www.textfiles.com/adventure/' + address)
            if ('.sol' in address):
                if (site == 1):
                    return_links.append('https://www.ifarchive.org/' + address.replace('../../../', ''))
    return return_links

# %%
def check_verb(token):
    """Check verb type given spacy token"""
    if token.pos_ == 'VERB':
        indirect_object = False
        direct_object = False
        for item in token.children:
            if(item.dep_ == "iobj" or item.dep_ == "pobj"):
                indirect_object = True
            if (item.dep_ == "dobj" or item.dep_ == "dative"):
                direct_object = True
        if indirect_object and direct_object:
            return 'DITRANVERB'
        elif direct_object and not indirect_object:
            return 'TRANVERB'
        elif not direct_object and not indirect_object:
            return 'INTRANVERB'
        else:
            return 'VERB'
    else:
        return token.pos_

# %%
links = (get_links("https://www.ifarchive.org/indexes/if-archive/solutions/", 1) + 
get_links("http://www.textfiles.com/adventure/", 2))

# %%
matcher = Matcher(nlp.vocab)
matcher.add('Action-Determiner-Object', None, [{POS: 'VERB'}, {POS: 'DET'}, {POS: 'ADJ', 'OP':'*'}, {POS: 'NOUN'}])

# %%
matcher2 = Matcher(nlp.vocab)
matcher2.add('Action-Determiner-Object', None, [{POS: 'VERB'}, {POS: 'DET'}, {POS: 'ADJ', 'OP':'*'}, {POS: 'NOUN'},
                                               {POS: 'ADP'}, {POS: 'DET'}, {POS: 'ADJ', 'OP':'*'}, {POS: 'NOUN'}])

# %%
commands = []
commands2 = []

# %%
len(links)
# Out:
# 306

# %%
doc = ""
for link in links:
    try:
        text = download_tutorial(link)
        doc = doc + " " + text
    except:
        print("file didn't work")
        pass
f = open('tutorials_2.txt', 'w')
f.write(doc)
f.close()
# Out:
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work

# %%
len(doc)
# Out:
# 15034

# %%
for i in range(0,100):
    try:
        text = download_tutorial(links[i])
    except:
        print("file didn't work")
        pass
    doc = nlp(text)
    matches = matcher(doc)
    matches2 = matcher2(doc)
    for match_id, start, end in matches:
        span = doc[start:end]
        verb = WordNetLemmatizer().lemmatize(str(nlp(span.text)[0]),'v')
        text = verb + " " + str(nlp(span.text)[1:])
        commands.append(text)
    for match_id, start, end in matches2:
        span = doc[start:end]
        verb = WordNetLemmatizer().lemmatize(str(nlp(span.text)[0]),'v')
        text = verb + " " + str(nlp(span.text)[1:])
        commands2.append(text)
# Out:
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work

# %%
for i in range(101,200):
    try:
        text = download_tutorial(links[i])
    except:
        print("file didn't work")
        pass
    doc = nlp(text)
    matches = matcher(doc)
    matches2 = matcher2(doc)
    for match_id, start, end in matches:
        span = doc[start:end]
        verb = WordNetLemmatizer().lemmatize(str(nlp(span.text)[0]),'v')
        text = verb + " " + str(nlp(span.text)[1:])
        commands.append(text)
    for match_id, start, end in matches2:
        span = doc[start:end]
        verb = WordNetLemmatizer().lemmatize(str(nlp(span.text)[0]),'v')
        text = verb + " " + str(nlp(span.text)[1:])
        commands2.append(text)
# Out:
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work

# %%
for i in range(201,305):
    try:
        text = download_tutorial(links[i])
    except:
        print("file didn't work")
        pass
    doc = nlp(text)
    matches = matcher(doc)
    matches2 = matcher2(doc)
    for match_id, start, end in matches:
        span = doc[start:end]
        verb = WordNetLemmatizer().lemmatize(str(nlp(span.text)[0]),'v')
        text = verb + " " + str(nlp(span.text)[1:])
        commands.append(text)
    for match_id, start, end in matches2:
        span = doc[start:end]
        verb = WordNetLemmatizer().lemmatize(str(nlp(span.text)[0]),'v')
        text = verb + " " + str(nlp(span.text)[1:])
        commands2.append(text)
# Out:
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work
# file didn't work

# %%
len(commands), len(commands2)
# Out:
# (13554, 1530)

# %%
with open('commands.txt', 'wb') as cmd:
    pickle.dump(commands, cmd)
with open('commands2.txt', 'wb') as cmd2:
    pickle.dump(commands2, cmd2)

# %%
import pandas as pd

# %%
verbs = []
for i in commands:
    verbs.append(str(nlp(i)[0]))

# %%
cm = pd.DataFrame(verbs)

# %%
cm[0] = cm[0].map(lambda x: x.lower())

# %%
for i in (cm[0].value_counts() > 1):
    print (cm[0])
# Out:
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# ...
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object
# 0        construct
# 1             cast
# 2           attack
# 3             pose
# 4             need
# 5             take
# 6               be
# 7           recall
# 8            throw
# 9             need
# 10         survive
# 11           enter
# 12           build
# 13          tinder
# 14            fork
# 15            keep
# 16           build
# 17            have
# 18             use
# 19          rotate
# 20           steer
# 21           build
# 22             get
# 23              be
# 24           knock
# 25            open
# 26             tie
# 27             tie
# 28             get
# 29             get
#            ...
# 13524         take
# 13525         open
# 13526      involve
# 13527         have
# 13528        reach
# 13529         take
# 13530         open
# 13531            s
# 13532        smack
# 13533         have
# 13534         open
# 13535         open
# 13536     remember
# 13537         hope
# 13538         have
# 13539      include
# 13540         find
# 13541           be
# 13542         open
# 13543        enter
# 13544        enter
# 13545      operate
# 13546         have
# 13547      examine
# 13548        leave
# 13549          get
# 13550         have
# 13551         kill
# 13552         find
# 13553          win
# Name: 0, Length: 13554, dtype: object

# %%
verbs_to_remove = ["be", "have", "s", "need", "do", "select", "save", "solve", "operate", "remember"]

# %%
more_than_few_occur = cm[0].value_counts()[cm[0].value_counts()>5]

# %%
verbs_to_keep = list(more_than_few_occur.index)
for i in verbs_to_remove:
    verbs_to_keep.remove(i)

# %%
for i in commands:
    if str(nlp(i)[0]).lower() not in verbs_to_keep:
        commands.remove(i)

# %%
commands
# Out:
# ['cast a stone',
#  'attack both monkeys',
#  'take this course',
#  'recall the hornets',
#  'throw the rock',
#  'survive the hornets',
#  'enter any corner',
#  'build a fire',
#  'fork the bucket',
#  'keep the fire',
#  'build the fire',
#  'use the fan',
#  'steer the mandrill',
#  'build the fire',
#  'get the bucket',
#  'knock the bucket',
#  'open the gate',
#  'tie the cord',
#  'tie the cord',
#  'get the bucket',
#  'get the bucket',
#  'use the barbecue',
#  'Getting the weight',
#  'drop the weight',
#  'Have the chimpanzee',
#  'remove the husk',
#  'read the previous section',
#  'get the gate',
#  'make some preparations',
#  'use the cord',
#  'remove the bucket',
#  'keep the gate',
#  'remove the cord',
#  'place an object',
#  'hold the gate',
#  'remove the bucket',
#  'retrieve the cord',
#  'require some timing',
#  'use that versatile tool',
#  'light the fuse',
#  'touch the torch',
#  'fly the cage',
#  'Using the procedure',
#  'make any difference',
#  'complete the puzzle',
#  'release the spirit',
#  'include a few fakes',
#  'read the answers',
#  'send an email',
#  'keep the bird',
#  'get the Persian rug',
#  'get the gold',
#  'navigate the maze',
#  'navigate the maze',
#  'get the flute',
#  'get the tusk',
#  'navigate the maze',
#  'turn the spoon',
#  'get the mask',
#  'get the orb',
#  'keep the vase',
#  'get a light source',
#  'cross the reservoir',
#  'get the sword',
#  'get the starstone',
#  'get the skeletons',
#  'learn all skeleton',
#  'change the time',
#  'Drink some water',
#  'include the building',
#  'take a small amount',
#  'finish the game',
#  'buy some batteries',
#  'use the appropriate magic words',
#  'drop an axe',
#  'learn a magic word',
#  'wear some protection',
#  'follow the instructions',
#  'call the owl',
#  'collect a bunch',
#  'get a nice reward',
#  'Follow the path',
#  'say the path',
#  'unlock the grate',
#  'learn a couple',
#  'make a good screwdriver',
#  'need the help',
#  'Catch the bird',
#  'keep the bird',
#  'read the instructions',
#  'enter the game',
#  'write Some objects',
#  'catch the bird',
#  'get the Persian rug',
#  'get the gold',
#  'use a magicword',
#  'say a magic word',
#  'Wave the rod',
#  'navigate the maze',
#  'make a grid',
#  'build a map',
#  'finish the game',
#  'navigate the maze',
#  'make a grid',
#  'ask the game',
#  'get the pirates',
#  'move each letter',
#  'get the flute',
#  'Is the figure',
#  'look a lot',
#  'go any direction',
#  'get the tusk',
#  'navigate the maze',
#  'leave the sewers',
#  'turn the spoon',
#  'guess the spoon',
#  'lose some stuff',
#  'bring the food',
#  'Bring the nest',
#  'eat the eggs',
#  'See the troll',
#  'engage the help',
#  'eat the spider',
#  'get the documents',
#  'cut the web',
#  'get the mask',
#  'tell the truth',
#  'get the orb',
#  'Get the orb',
#  'get the orb',
#  'play the game',
#  'use the visions',
#  'find the crucifix',
#  'need the wizards',
#  'Read the description',
#  'fill the chalice',
#  'drink some strange things',
#  'lose the chalice',
#  'help the princess',
#  'type the name',
#  'avoid the problem',
#  'keep the vase',
#  'drop the pillow',
#  'get a light source',
#  'carry a light source',
#  'get a light source',
#  'carry the trident',
#  'Create a bridge',
#  'Read the games',
#  'wave the rod',
#  'wave the rod',
#  'cross the reservoir',
#  'use the yacht',
#  'Read the games',
#  'Hit the gong',
#  'get the sword',
#  'Eat the mushroom',
#  'Throw the sword',
#  'drop the starstone',
#  'Fight the green slime',
#  'Throw the vial',
#  'miss the sculpture',
#  'spell a fiveletter word',
#  'use that word',
#  'get the response',
#  'Use the keys',
#  'unlock the chain',
#  'cross the bridge',
#  'Make a bridge',
#  'turn the sword',
#  'Use a magic word',
#  'find the sword',
#  'use the proper tool',
#  'grow an army',
#  'suggest a question',
#  'Drop the flask',
#  'get the starstone',
#  'Use the old mirror',
#  'carry the rags',
#  'determine the layout',
#  'move the same way',
#  'leave the area',
#  'get the skeletons',
#  'suggest a skeleton',
#  'Use the magic word',
#  'use the right one',
#  'learn all skeleton',
#  'wear the crown',
#  'consider a magic word',
#  'like the idea',
#  'Say the words',
#  'wear the crown',
#  'think the hints',
#  'discover each treasure',
#  'leave each treasure',
#  'take a hint',
#  'be an adaptation',
#  'contain the walkthroughs',
#  'write some mild AI',
#  'recommend the Web',
#  'be a small pit',
#  'catch the bird',
#  'be another magic word',
#  'fee a hungry bear',
#  'unlock a tame bear',
#  'throw an axe',
#  'Take this axe',
#  'ignore the dwarf',
#  'want a thirsty plant',
#  'need this oil',
#  'cross the bridge',
#  'open a clam',
#  'contain a pearl',
#  'take the vase',
#  'see the pirate',
#  'forget that advice',
#  'hear an announcement',
#  'announce This exit',
#  'Note Some variables',
#  'Note the combination',
#  'turn the dial',
#  'learn the name',
#  'uncover a pattern',
#  'Turn w Turn',
#  'hear the righthand',
#  'restart the game',
#  'follow this procedure',
#  'cover both hole',
#  'light a match',
#  'light the lantern',
#  'change each time',
#  'restart the game',
#  'find the mirror',
#  'have the same measure',
#  'Remember the last time',
#  'be a mediumlong',
#  'include a great deal',
#  'win the game',
#  'examine the room',
#  'make no difference',
#  'enjoy a nice game',
#  'find the optimal route',
#  'navigate the signs',
#  'break the ice',
#  'drop the shiny shiny your friends',
#  'try some deserted workshop',
#  'give the commands',
#  'group the actions',
#  'follow this solution',
#  'involve some backtracking',
#  'follow the walkthrough',
#  'get the password',
#  'determine each game',
#  'get the matches',
#  'get the cinder',
#  'get the red script',
#  'get the green script',
#  'get the yellow script',
#  'get the pink script',
#  'get the blue script',
#  'find the woman',
#  'type a password',
#  'examine the torch',
#  'insert the batter',
#  'throw the rope',
#  'move some bookcases',
#  'block the bottom',
#  'need the staff',
#  'explore the apartment',
#  'find some clue',
#  'Read the message',
#  'take the binoculars',
#  'find the key',
#  'find the light switch',
#  'have a sense',
#  'do some exploring',
#  'show an interest',
#  'make a propositionget',
#  'get the libation',
#  'enter the back',
#  'use that door',
#  'Read the ledger',
#  'get the key',
#  'give a bottle',
#  'close the bottle',
#  'enter the building',
#  'find the roll',
#  'take all takeable items',
#  'notice a hatch',
#  'give some clueyoure',
#  'Try some thingsturn',
#  'get a feel',
#  'find a scaffold examine',
#  'throw this balance',
#  'get a feel',
#  'turn the crank',
#  'go the other direction',
#  'want the tub',
#  'Let the messages',
#  'put some energy',
#  'put the staff',
#  'cross the street',
#  'give the nametag',
#  'figure this one',
#  'open the gratingyoure',
#  'notice the screwdriver',
#  'take the screwdriver',
#  'take the shirt',
#  'take the glasses',
#  'be a sheet',
#  'get this sheet',
#  'Take the magazine',
#  'take the towelyoull need',
#  'replace the sheet',
#  'take the sheet',
#  'put the towel',
#  'give the towel',
#  'see a yellow streamer',
#  'Using the binocs',
#  'Remember the suggestion',
#  'give the ticket',
#  'open this skylight',
#  'leave the park',
#  'notice no one',
#  'start the ride',
#  'get a white paper',
#  'take the bag',
#  'leave the bag',
#  'stop the wheel',
#  'stop the wheel',
#  'use the remaining time',
#  'give the popcorn',
#  'throw the rock',
#  'let the ride',
#  'type a command',
#  'let the ride',
#  'make the important choices',
#  'put the pipe',
#  'Seen any demolished buildings',
#  'do this rightand',
#  'see these things',
#  'hear the blast',
#  'get a look',
#  'see the hawk',
#  'get a leg',
#  'set the bomb',
#  'set that bomb',
#  'have the diary',
#  'Get a look',
#  'get a surprise',
#  'hold some meaning',
#  'use the remaining time',
#  'take a nap',
#  'Follow the messages',
#  'leave the bedand',
#  'see the words',
#  'make the right choice',
#  'get a snarky response',
#  'Remember the closet',
#  'WHISPER the magic word',
#  'Take the mojo',
#  'get a package',
#  'Take the black box',
#  'find the important thingits',
#  'notice some other strange things',
#  'take a walk',
#  'read the note',
#  'find some shoes',
#  'leave the rope',
#  'see the sphere',
#  'unlock the gate',
#  'take the curious object',
#  'be a switchblade',
#  'take the bandanna',
#  'become a giant bird',
#  'take the mojo',
#  'Push the little button',
#  'leave the cell',
#  'open the steam',
#  'want some laughs',
#  'wear the light stick',
#  'find a leather',
#  'follow the path',
#  'have a huge black dotthis',
#  'unlock the white door',
#  'examine the huge book',
#  'Examine the firewhats',
#  'get the points',
#  'Put the nametag',
#  'examine the hole',
#  'wear onethe nametagas',
#  'make a ropewith',
#  'untie the leather',
#  'give the mojo',
#  'say that word',
#  'say the magic word',
#  'give the mojo',
#  'watch the pyrotechnics',
#  'get the fedorawith',
#  'run the gate',
#  're a slow typist',
#  'make a noise',
#  'upset no difference',
#  'die nog niet openen',
#  'be nog niet dood',
#  'make a mistake',
#  'see the death',
#  'visit the room',
#  'let the thief',
#  'Turn the tables',
#  'make the thief',
#  'eat the different cakes',
#  'examine the portrait',
#  'take the bat',
#  'read the card',
#  'open the grating',
#  'burn the black book',
#  'damage the painting',
#  'light the candles',
#  'read the matchbook',
#  'get the stamp',
#  'kick the bucket',
#  'burn a few different items',
#  'read the writing',
#  'see the map',
#  'let the thief',
#  'STEAL the coffin',
#  'leave the room',
#  'GIVE A DAM',
#  'hope the thief',
#  'remember this place',
#  'KILL A THIEF',
#  'drop the candles',
#  'follow a stepbystep',
#  'enter the mirror',
#  'enter the robbers',
#  'determine the function',
#  'be the absolute minimum specified value',
#  'indicate the locations',
#  'disappear a sardonic grin',
#  'WANTED THE RANKINGS',
#  'cast a stone',
#  'attack both monkeys',
#  'take this course',
#  'recall the hornets',
#  'throw the rock',
#  'need the chimpanzee',
#  'survive the hornets',
#  'enter any corner',
#  'build a fire',
#  'fork the bucket',
#  'keep the fire',
#  'build the fire',
#  'use the fan',
#  'steer the mandrill',
#  'build the fire',
#  'get the bucket',
#  'knock the bucket',
#  'open the gate',
#  'tie the cord',
#  'tie the cord',
#  'get the bucket',
#  'get the bucket',
#  'use the barbecue',
#  'Getting the weight',
#  'drop the weight',
#  'Have the chimpanzee',
#  'need the chimpanzee',
#  'remove the husk',
#  'read the previous section',
#  'get the gate',
#  'make some preparations',
#  'use the cord',
#  'remove the bucket',
#  'keep the gate',
#  'remove the cord',
#  'place an object',
#  'hold the gate',
#  'remove the bucket',
#  'retrieve the cord',
#  'require some timing',
#  'use that versatile tool',
#  'light the fuse',
#  'touch the torch',
#  'fly the cage',
#  'Using the procedure',
#  'make any difference',
#  'complete the puzzle',
#  'Remember the magic word',
#  'release the spirit',
#  'include a few fakes',
#  'read the answers',
#  'send an email',
#  's the meaning',
#  'keep the bird',
#  'get the Persian rug',
#  'get the gold',
#  'navigate the maze',
#  'navigate the maze',
#  'get the flute',
#  'be the magazines',
#  'get the tusk',
#  'navigate the maze',
#  'turn the spoon',
#  'get the mask',
#  'get the orb',
#  'be the crypt',
#  'keep the vase',
#  'get a light source',
#  'cross the reservoir',
#  'get the sword',
#  'be the pentagram',
#  'get the starstone',
#  'get the skeletons',
#  'learn all skeleton',
#  'change the time',
#  'Drink some water',
#  'include the building',
#  'take a small amount',
#  'finish the game',
#  'buy some batteries',
#  'use the appropriate magic words',
#  'drop an axe',
#  'learn a magic word',
#  'wear some protection',
#  'follow the instructions',
#  'call the owl',
#  'collect a bunch',
#  'get a nice reward',
#  'Follow the path',
#  'say the path',
#  'unlock the grate',
#  'learn a couple',
#  'make a good screwdriver',
#  's the meaning',
#  'need the help',
#  'Catch the bird',
#  'keep the bird',
#  'read the instructions',
#  'enter the game',
#  'write Some objects',
#  'catch the bird',
#  'get the Persian rug',
#  'get the gold',
#  'use a magicword',
#  'say a magic word',
#  'Wave the rod',
#  'navigate the maze',
#  'make a grid',
#  'build a map',
#  'finish the game',
#  'navigate the maze',
#  'distinguish the rooms',
#  'distinguish the rooms',
#  'make a grid',
#  'ask the game',
#  'get the pirates',
#  'move each letter',
#  'get the flute',
#  'Is the figure',
#  'look a lot',
#  'be the magazines',
#  'go any direction',
#  'get the tusk',
#  'navigate the maze',
#  'leave the sewers',
#  'turn the spoon',
#  'guess the spoon',
#  'lose some stuff',
#  'bring the food',
#  'Bring the nest',
#  'eat the eggs',
#  'See the troll',
#  'engage the help',
#  'eat the spider',
#  'get the documents',
#  'cut the web',
#  'get the mask',
#  'tell the truth',
#  'get the orb',
#  'Get the orb',
#  'get the orb',
#  'play the game',
#  'use the visions',
#  'be the crypt',
#  'find the crucifix',
#  'need the wizards',
#  'Read the description',
#  'fill the chalice',
#  'drink some strange things',
#  'lose the chalice',
#  'help the princess',
#  'type the name',
#  'avoid the problem',
#  'keep the vase',
#  'drop the pillow',
#  'get a light source',
#  'carry a light source',
#  'get a light source',
#  'carry the trident',
#  'Create a bridge',
#  'Read the games',
#  'wave the rod',
#  'wave the rod',
#  'cross the reservoir',
#  'use the yacht',
#  'Read the games',
#  'Hit the gong',
#  'get the sword',
#  'Eat the mushroom',
#  'Throw the sword',
#  'drop the starstone',
#  'Fight the green slime',
#  'Throw the vial',
#  'miss the sculpture',
#  'spell a fiveletter word',
#  'use that word',
#  'get the response',
#  'Use the keys',
#  'unlock the chain',
#  'cross the bridge',
#  'Make a bridge',
#  'turn the sword',
#  'Use a magic word',
#  'find the sword',
#  'use the proper tool',
#  'grow an army',
#  'suggest a question',
#  'be the pentagram',
#  'Drop the flask',
#  'get the starstone',
#  'Use the old mirror',
#  'carry the rags',
#  'determine the layout',
#  'move the same way',
#  'leave the area',
#  'get the skeletons',
#  'suggest a skeleton',
#  'Use the magic word',
#  'use the right one',
#  'learn all skeleton',
#  'wear the crown',
#  'consider a magic word',
#  'like the idea',
#  'Say the words',
#  'wear the crown',
#  'think the hints',
#  'discover each treasure',
#  'leave each treasure',
#  'take a hint',
#  'be an adaptation',
#  'contain the walkthroughs',
#  'write some mild AI',
#  'recommend the Web',
#  'be a small pit',
#  'catch the bird',
#  'be another magic word',
#  'fee a hungry bear',
#  'unlock a tame bear',
#  'throw an axe',
#  'Take this axe',
#  'ignore the dwarf',
#  'want a thirsty plant',
#  'need this oil',
#  'cross the bridge',
#  'open a clam',
#  'contain a pearl',
#  'take the vase',
#  'be a magic wand',
#  'see the pirate',
#  'forget that advice',
#  'hear an announcement',
#  'announce This exit',
#  'Note Some variables',
#  'Note the combination',
#  'turn the dial',
#  'learn the name',
#  'uncover a pattern',
#  'Turn w Turn',
#  'hear the righthand',
#  'restart the game',
#  'follow this procedure',
#  'cover both hole',
#  'light a match',
#  'light the lantern',
#  'change each time',
#  'restart the game',
#  'find the mirror',
#  'have the same measure',
#  'Remember the last time',
#  'be a mediumlong',
#  'include a great deal',
#  'win the game',
#  'examine the room',
#  'be a few different things',
#  'make no difference',
#  'enjoy a nice game',
#  'find the optimal route',
#  'navigate the signs',
#  'break the ice',
#  'be a few different things',
#  'drop the shiny shiny your friends',
#  'try some deserted workshop',
#  'give the commands',
#  'group the actions',
#  'follow this solution',
#  'involve some backtracking',
#  'follow the walkthrough',
#  'get the password',
#  'determine each game',
#  'get the matches',
#  'get the cinder',
#  'get the red script',
#  'get the green script',
#  'get the yellow script',
#  'get the pink script',
#  'get the blue script',
#  'find the woman',
#  'type a password',
#  'examine the torch',
#  'insert the batter',
#  'throw the rope',
#  'move some bookcases',
#  'block the bottom',
#  'be a few times',
#  'need the staff',
#  'explore the apartment',
#  'find some clue',
#  'Read the message',
#  'take the binoculars',
#  'find the key',
#  'find the light switch',
#  'have a sense',
#  'do some exploring',
#  'show an interest',
#  'make a propositionget',
#  'get the libation',
#  'enter the back',
#  'use that door',
#  'Read the ledger',
#  'get the key',
#  'give a bottle',
#  'close the bottle',
#  'enter the building',
#  'find the roll',
#  'take all takeable items',
#  'notice a hatch',
#  'give some clueyoure',
#  'Try some thingsturn',
#  'get a feel',
#  'find a scaffold examine',
#  'throw this balance',
#  'get a feel',
#  'turn the crank',
#  'go the other direction',
#  'want the tub',
#  'Let the messages',
#  'put some energy',
#  'put the staff',
#  'cross the street',
#  'give the nametag',
#  'figure this one',
#  'open the gratingyoure',
#  'notice the screwdriver',
#  'take the screwdriver',
#  'take the shirt',
#  'take the glasses',
#  'be a sheet',
#  'get this sheet',
#  'Take the magazine',
#  'take the towelyoull need',
#  'replace the sheet',
#  'take the sheet',
#  'put the towel',
#  'give the towel',
#  'see a yellow streamer',
#  'Using the binocs',
#  'Remember the suggestion',
#  'give the ticket',
#  'open this skylight',
#  'leave the park',
#  'notice no one',
#  'start the ride',
#  'get a white paper',
#  'take the bag',
#  'leave the bag',
#  'stop the wheel',
#  'stop the wheel',
#  'use the remaining time',
#  'give the popcorn',
#  'throw the rock',
#  'let the ride',
#  'type a command',
#  'let the ride',
#  'make the important choices',
#  'put the pipe',
#  'Seen any demolished buildings',
#  'do this rightand',
#  'see these things',
#  'hear the blast',
#  'get a look',
#  'see the hawk',
#  'get a leg',
#  'set the bomb',
#  'set that bomb',
#  'have the diary',
#  'Get a look',
#  'get a surprise',
#  'hold some meaning',
#  'use the remaining time',
#  'take a nap',
#  'Follow the messages',
#  'leave the bedand',
#  'see the words',
#  'make the right choice',
#  'get a snarky response',
#  'Remember the closet',
#  'WHISPER the magic word',
#  'be the mojo',
#  'Take the mojo',
#  'get a package',
#  'Take the black box',
#  'find the important thingits',
#  'notice some other strange things',
#  'take a walk',
#  'read the note',
#  'find some shoes',
#  'leave the rope',
#  'see the sphere',
#  'unlock the gate',
#  'take the curious object',
#  'be a switchblade',
#  'take the bandanna',
#  'become a giant bird',
#  'take the mojo',
#  'Push the little button',
#  'leave the cell',
#  'be the mojo',
#  'open the steam',
#  'want some laughs',
#  'wear the light stick',
#  'find a leather',
#  'follow the path',
#  'have a huge black dotthis',
#  'unlock the white door',
#  'examine the huge book',
#  'Examine the firewhats',
#  'get the points',
#  'Put the nametag',
#  'examine the hole',
#  'wear onethe nametagas',
#  'make a ropewith',
#  'untie the leather',
#  'give the mojo',
#  'Remember the magic word',
#  'say that word',
#  'say the magic word',
#  'give the mojo',
#  'watch the pyrotechnics',
#  'get the fedorawith',
#  'run the gate',
#  're a slow typist',
#  'make a noise',
#  'solve the puzzles',
#  'solve the puzzles',
#  'upset no difference',
#  'die nog niet openen',
#  'be nog niet dood',
#  'make a mistake',
#  'see the death',
#  'visit the room',
#  'let the thief',
#  'Turn the tables',
#  'make the thief',
#  'eat the different cakes',
#  'examine the portrait',
#  'take the bat',
#  'read the card',
#  'open the grating',
#  'burn the black book',
#  'damage the painting',
#  'light the candles',
#  'read the matchbook',
#  'get the stamp',
#  'kick the bucket',
#  'burn a few different items',
#  'read the writing',
#  'see the map',
#  'let the thief',
#  'STEAL the coffin',
#  'leave the room',
#  'GIVE A DAM',
#  'hope the thief',
#  'be a magic wand',
#  'remember this place',
#  'KILL A THIEF',
#  'drop the candles',
#  'follow a stepbystep',
#  'enter the mirror',
#  'enter the robbers',
#  'determine the function',
#  'be the absolute minimum specified value',
#  'be the ultimate storehouse',
#  'indicate the locations',
#  'disappear a sardonic grin',
#  'WANTED THE RANKINGS',
#  'be the ultimate storehouse',
#  'escape the castle',
#  'complete the wholestory',
#  'be a painting',
#  'reveal a secret passage',
#  'explore the castle',
#  'pass the west door',
#  'Passing the dragon',
#  'Choose the one',
#  'be an armor',
#  'See the candles',
#  'Get a set',
#  'Bring the set',
#  'find a bridge',
#  'grab the book',
#  'cross the bridge',
#  'Bring the book',
#  'Get the cross',
#  'reveal a downward passage',
#  'get the wand',
#  'kiss the frog',
#  'become a princess',
#  'say the return',
#  'wave the wand',
#  'Take a lot',
#  'Get the bell',
#  'pour the water',
#  'Get the secateur',
#  'find a windlass',
#  'lower the drawbridge',
#  'cut the rope',
#  'bring the bell',
#  'take a golden key',
#  'say the magic word',
#  'demolish the castle',
#  'say the magic word',
#  'distribute this document',
#  'call the garage',
#  'call the garage',
#  'find a rubber',
#  'find a key',
#  'find a pocket',
#  'be a hard way',
#  'change the time',
#  'stem The time',
#  'stem The time',
#  'stem The video',
#  'stem The time',
#  'cause the time',
#  'be the foundation',
#  'stem The time',
#  'increase the minutes',
#  'change the hour',
#  'like the number',
#  'get a package',
#  'reveal a can',
#  'stem The time',
#  'stem The time',
#  'stem The time',
#  'stem The time',
#  'stem The time',
#  'get a package',
#  'reveal the second can',
#  'stem The time',
#  'stem The time',
#  'stem The time',
#  'stem The time',
#  'bear some resemblance',
#  'stem The time',
#  'stem The time',
#  'find the towel',
#  'stem The sound system',
#  'stem The sound system',
#  'stem The video',
#  'get a package',
#  'reveal the third can',
#  'stem The video',
#  'reveal the fish',
#  'get a package',
#  'reveal the fourth can',
#  'get a package',
#  'reveal the fifth can',
#  'read the time',
#  'Set the pocket',
#  'have no towel',
#  'mention the dog',
#  'find the ball',
#  'hear a click',
#  'set the table',
#  'set the table',
#  'throw the ball',
#  'see the dog',
#  'find the dog',
#  'use this feature',
#  ...]
