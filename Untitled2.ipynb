# %%
from agent import DQNAgent
from game import text_game
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\sparr\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sparr\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
g = text_game()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-70135805462d> in <module>
# ----> 1 g = text_game()
#
# ~\Desktop\datascience\dsc-5-capstone-project-online-ds-sp-000\game.py in __init__(self)
#      82     # read line without blocking
#      83     def readLine(self, q):
# ---> 84         cont = True
#      85         narrative = ""
#      86         while cont:
#
# NameError: name 'pd' is not defined

# %%
import importlib
import game
import agent
importlib.reload(game)
# Out:
# <module 'game' from 'C:\\Users\\sparr\\Desktop\\datascience\\dsc-5-capstone-project-online-ds-sp-000\\game.py'>
